# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Aeronaves

# %%
df_aero = pd.read_excel(r"C:\Users\Murilo\Desktop\01 - portfolio and repository\Acme Aero\files\aero_aeronave.xlsx")
df_aero.head()
# Out:
#    codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0               39115              PTNQX                         ***
# 1               39155              PTLVI                         ***
# 2               39156              PPPTO                         ***
# 3               39158              PRLGJ                     REGULAR
# 4               39176              PRMAA                     REGULAR
#
#   aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# 0                 AVIÃO  NEIVA INDUSTRIA AERONAUTICA        EMB-711A
# 1                 AVIÃO               BEECH AIRCRAFT             C90
# 2                 AVIÃO      AEROSPATIALE AND ALENIA     ATR-72-212A
# 3                 AVIÃO               BOEING COMPANY         757-225
# 4                 AVIÃO             AIRBUS INDUSTRIE        A320-232
#
#   aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# ...

# %%
df_aero.tail()
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 5816               79802              PRGUF                         ***
# 5817               79804              PRAJZ                         ***
# 5818               79824              PRALA                         ***
# 5819               79844              PRJBP                         ***
# 5820               79874              *****                         ***
#
#      aeronave_tipo_veiculo      aeronave_fabricante      aeronave_modelo  \
# 5816                 AVIÃO           BOEING COMPANY              737-8EH
# 5817                   ***           BOEING COMPANY              737-48E
# 5818                 AVIÃO           PIPER AIRCRAFT            PA-25-235
# 5819           HELICÓPTERO        SIKORSKY AIRCRAFT                S-92A
# 5820                   ***  FABRICANTE DESCONHECIDO  MODELO DESCONHECIDO
#
#      aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# ...

# %%
df_aero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5821 entries, 0 to 5820
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   codigo_ocorrencia2           5821 non-null   int64
#  1   aeronave_matricula           5821 non-null   object
#  2   aeronave_operador_categoria  5821 non-null   object
#  3   aeronave_tipo_veiculo        5821 non-null   object
#  4   aeronave_fabricante          5821 non-null   object
#  5   aeronave_modelo              5821 non-null   object
#  6   aeronave_tipo_icao           5821 non-null   object
#  7   aeronave_motor_tipo          5821 non-null   object
#  8   aeronave_motor_quantidade    5821 non-null   object
#  9   aeronave_pmd                 5821 non-null   int64
#  10  aeronave_pmd_categoria       5821 non-null   int64
#  11  aeronave_assentos            5670 non-null   float64
#  12  aeronave_ano_fabricacao      5671 non-null   float64
# ...

# %%
df_aero.describe(include="object").T
# Out:
#                             count unique                top  freq
# aeronave_matricula           5821   4250              *****    13
# aeronave_operador_categoria  5821     12                ***  2793
# aeronave_tipo_veiculo        5821     10              AVIÃO  4683
# aeronave_fabricante          5821    239    CESSNA AIRCRAFT   903
# aeronave_modelo              5821    802        ATR-72-212A   189
# aeronave_tipo_icao           5821    236               PA34   421
# aeronave_motor_tipo          5821      6             PISTÃO  3248
# aeronave_motor_quantidade    5821      6          MONOMOTOR  2959
# aeronave_pais_fabricante     5821     22             BRASIL  5709
# aeronave_pais_registro       5821     22             BRASIL  5709
# aeronave_registro_categoria  5821     10              AVIÃO  4683
# aeronave_registro_segmento   5821     13         PARTICULAR  1777
# aeronave_voo_origem          5821    667  FORA DE AERODROMO  2733
# ...

# %%
df_aero.nunique()
# Out:
# codigo_ocorrencia2             5752
# aeronave_matricula             4250
# aeronave_operador_categoria      12
# aeronave_tipo_veiculo            10
# aeronave_fabricante             239
# aeronave_modelo                 802
# aeronave_tipo_icao              236
# aeronave_motor_tipo               6
# aeronave_motor_quantidade         6
# aeronave_pmd                    485
# aeronave_pmd_categoria          485
# aeronave_assentos                91
# aeronave_ano_fabricacao          80
# aeronave_pais_fabricante         22
# aeronave_pais_registro           22
# aeronave_registro_categoria      10
# aeronave_registro_segmento       13
# aeronave_voo_origem             667
# aeronave_voo_destino            665
# aeronave_fase_operacao           32
# aeronave_tipo_operacao           10
# aeronave_nivel_dano               5
# aeronave_fatalidades_total       11
# dtype: int64

# %%
df_aero.isnull().sum()
# Out:
# codigo_ocorrencia2               0
# aeronave_matricula               0
# aeronave_operador_categoria      0
# aeronave_tipo_veiculo            0
# aeronave_fabricante              0
# aeronave_modelo                  0
# aeronave_tipo_icao               0
# aeronave_motor_tipo              0
# aeronave_motor_quantidade        0
# aeronave_pmd                     0
# aeronave_pmd_categoria           0
# aeronave_assentos              151
# aeronave_ano_fabricacao        150
# aeronave_pais_fabricante         0
# aeronave_pais_registro           0
# aeronave_registro_categoria      0
# aeronave_registro_segmento       0
# aeronave_voo_origem              0
# aeronave_voo_destino             0
# aeronave_fase_operacao           0
# aeronave_tipo_operacao           0
# aeronave_nivel_dano              0
# aeronave_fatalidades_total       0
# dtype: int64

# %%
# calcular a porcentagem de dados faltantes
pd.DataFrame(df_aero.isnull().sum(axis=0)).sort_values(by=0, ascending=False)/df_aero.shape[0]*100
# Out:
#                                     0
# aeronave_assentos            2.594056
# aeronave_ano_fabricacao      2.576877
# aeronave_nivel_dano          0.000000
# aeronave_tipo_operacao       0.000000
# aeronave_fase_operacao       0.000000
# aeronave_voo_destino         0.000000
# aeronave_voo_origem          0.000000
# aeronave_registro_segmento   0.000000
# aeronave_registro_categoria  0.000000
# aeronave_pais_registro       0.000000
# aeronave_pais_fabricante     0.000000
# codigo_ocorrencia2           0.000000
# aeronave_matricula           0.000000
# aeronave_pmd_categoria       0.000000
# aeronave_pmd                 0.000000
# aeronave_motor_quantidade    0.000000
# aeronave_motor_tipo          0.000000
# aeronave_tipo_icao           0.000000
# aeronave_modelo              0.000000
# aeronave_fabricante          0.000000
# aeronave_tipo_veiculo        0.000000
# aeronave_operador_categoria  0.000000
# aeronave_fatalidades_total   0.000000

# %%
df_aero["aeronave_operador_categoria"].value_counts()
# Out:
# ***                       2793
# REGULAR                    889
# PARTICULAR                 724
# TÁXI AÉREO                 487
# INSTRUÇÃO                  387
# EXPERIMENTAL               347
# ADMINISTRAÇÃO DIRETA       104
# ESPECIALIZADA               40
# AGRÍCOLA                    23
# NÃO REGULAR                 17
# MÚLTIPLA                     9
# ADMINISTRAÇÃO INDIRETA       1
# Name: aeronave_operador_categoria, dtype: int64

# %%
df_aero["aeronave_operador_categoria"].value_counts(normalize = True)*100
# Out:
# ***                       47.981446
# REGULAR                   15.272290
# PARTICULAR                12.437725
# TÁXI AÉREO                 8.366260
# INSTRUÇÃO                  6.648342
# EXPERIMENTAL               5.961175
# ADMINISTRAÇÃO DIRETA       1.786635
# ESPECIALIZADA              0.687167
# AGRÍCOLA                   0.395121
# NÃO REGULAR                0.292046
# MÚLTIPLA                   0.154613
# ADMINISTRAÇÃO INDIRETA     0.017179
# Name: aeronave_operador_categoria, dtype: float64

# %% [markdown]
# # Fator Contribuinte

# %%
df_fc = pd.read_excel(r"C:\Users\Murilo\Desktop\01 - portfolio and repository\Acme Aero\files\aero_FatorContribuinte.xlsx")
df_fc.head()
# Out:
#    codigo_ocorrencia3                   fator_nome             fator_aspecto  \
# 0               39115        APLICAÇÃO DE COMANDOS  DESEMPENHO DO SER HUMANO
# 1               39115      JULGAMENTO DE PILOTAGEM  DESEMPENHO DO SER HUMANO
# 2               39115                    PERCEPÇÃO       ASPECTO PSICOLÓGICO
# 3               39115          PLANEJAMENTO DE VOO  DESEMPENHO DO SER HUMANO
# 4               39115  POUCA EXPERIÊNCIA DO PILOTO  DESEMPENHO DO SER HUMANO
#
#     fator_condicionante         fator_area
# 0  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 1  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 2            INDIVIDUAL       FATOR HUMANO
# 3  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL
# 4  OPERAÇÃO DA AERONAVE  FATOR OPERACIONAL

# %%
df_fc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4161 entries, 0 to 4160
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_ocorrencia3   4161 non-null   int64
#  1   fator_nome           4161 non-null   object
#  2   fator_aspecto        4161 non-null   object
#  3   fator_condicionante  4161 non-null   object
#  4   fator_area           4161 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 162.7+ KB

# %%
df_fc.describe(include="object").T
# Out:
#                     count unique                       top  freq
# fator_nome           4161     73   JULGAMENTO DE PILOTAGEM   553
# fator_aspecto        4161     12  DESEMPENHO DO SER HUMANO  2523
# fator_condicionante  4161      7      OPERAÇÃO DA AERONAVE  2257
# fator_area           4161      5         FATOR OPERACIONAL  2720

# %%
df_fc.isnull().sum()
# Out:
# codigo_ocorrencia3     0
# fator_nome             0
# fator_aspecto          0
# fator_condicionante    0
# fator_area             0
# dtype: int64

# %% [markdown]
# # Ocorrencia Tipo

# %%
df_ot = pd.read_excel(r"C:\Users\Murilo\Desktop\01 - portfolio and repository\Acme Aero\files\aero_ocorrenciaTipo.xlsx")
df_ot.head()
# Out:
#    codigo_ocorrencia1                                    ocorrencia_tipo  \
# 0               39115                                          PANE SECA
# 1               39155                           VAZAMENTO DE COMBUSTÍVEL
# 2               39156                                        FOGO EM VOO
# 3               39158                                   SUPERAQUECIMENTO
# 4               39176  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...
#
#                            ocorrencia_tipo_categoria taxonomia_tipo_icao
# 0                            COMBUSTÍVEL | PANE SECA                FUEL
# 1  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...              SCF-NP
# 2            FOGO/FUMAÇA (SEM IMPACTO) | FOGO EM VOO                F-NI
# 3  FALHA OU MAU FUNCIONAMENTO DO MOTOR | SUPERAQU...              SCF-PP
# 4  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...              SCF-NP

# %%
df_ot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5884 entries, 0 to 5883
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   codigo_ocorrencia1         5884 non-null   int64
#  1   ocorrencia_tipo            5884 non-null   object
#  2   ocorrencia_tipo_categoria  5884 non-null   object
#  3   taxonomia_tipo_icao        5884 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 184.0+ KB

# %%
df_ot.describe(include="object").T
# Out:
#                           count unique  \
# ocorrencia_tipo            5884     79
# ocorrencia_tipo_categoria  5884     79
# taxonomia_tipo_icao        5884     31
#
#                                                                          top  \
# ocorrencia_tipo                                        FALHA DO MOTOR EM VOO
# ocorrencia_tipo_categoria  FALHA OU MAU FUNCIONAMENTO DO MOTOR | FALHA DO...
# taxonomia_tipo_icao                                                   SCF-NP
#
#                            freq
# ocorrencia_tipo             723
# ocorrencia_tipo_categoria   723
# taxonomia_tipo_icao        1841

# %%
df_ot.isnull().sum()
# Out:
# codigo_ocorrencia1           0
# ocorrencia_tipo              0
# ocorrencia_tipo_categoria    0
# taxonomia_tipo_icao          0
# dtype: int64

# %% [markdown]
# # Ocorrencia

# %%
df_oco = pd.read_excel(r"C:\Users\Murilo\Desktop\01 - portfolio and repository\Acme Aero\files\aero_ocorrencia.xlsx")
df_oco.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df_oco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5752 entries, 0 to 5751
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   codigo_ocorrencia               5752 non-null   int64
#  1   codigo_ocorrencia1              5752 non-null   int64
#  2   codigo_ocorrencia2              5752 non-null   int64
#  3   codigo_ocorrencia3              5752 non-null   int64
#  4   codigo_ocorrencia4              5752 non-null   int64
#  5   ocorrencia_classificacao        5752 non-null   object
#  6   ocorrencia_latitude             4187 non-null   object
#  7   ocorrencia_longitude            4187 non-null   object
#  8   ocorrencia_cidade               5752 non-null   object
#  9   ocorrencia_uf                   5752 non-null   object
#  10  ocorrencia_pais                 5752 non-null   object
#  11  ocorrencia_aerodromo            5752 non-null   object
# ...

# %%
#procentagem de nulos muito alta em apenas uma coluna
pd.DataFrame(df_oco.isnull().sum(axis=0)).sort_values(by=0, ascending=False)/df_oco.shape[0]*100
# Out:
#                                         0
# divulgacao_dia_publicacao       74.026426
# ocorrencia_latitude             27.207928
# ocorrencia_longitude            27.207928
# divulgacao_relatorio_numero     15.038248
# investigacao_aeronave_liberada   5.928373
# investigacao_status              5.910987
# ocorrencia_hora                  0.017385
# codigo_ocorrencia                0.000000
# ocorrencia_dia                   0.000000
# total_aeronaves_envolvidas       0.000000
# total_recomendacoes              0.000000
# divulgacao_relatorio_publicado   0.000000
# ocorrencia_aerodromo             0.000000
# codigo_ocorrencia1               0.000000
# ocorrencia_pais                  0.000000
# ocorrencia_uf                    0.000000
# ocorrencia_cidade                0.000000
# ocorrencia_classificacao         0.000000
# codigo_ocorrencia4               0.000000
# codigo_ocorrencia3               0.000000
# codigo_ocorrencia2               0.000000
# ...

# %%
df_oco.describe(include="object").T
# Out:
#                                count unique             top  freq
# ocorrencia_classificacao        5752      3       INCIDENTE  3171
# ocorrencia_latitude             4187   2480             ***   726
# ocorrencia_longitude            4187   2476             ***   727
# ocorrencia_cidade               5752   1099  RIO DE JANEIRO   321
# ocorrencia_uf                   5752     28              SP  1373
# ocorrencia_pais                 5752      1          BRASIL  5752
# ocorrencia_aerodromo            5752    515            ****  2181
# ocorrencia_dia                  5752   2971      2013-12-18     9
# ocorrencia_hora                 5751    967        20:00:00   123
# investigacao_aeronave_liberada  5411      3             SIM  3221
# investigacao_status             5412      2      FINALIZADA  4911
# divulgacao_relatorio_numero     4887   1677             ***  2928
# divulgacao_relatorio_publicado  5752      2             NÃO  4265
# ...

# %%
df_oco.nunique()
# Out:
# codigo_ocorrencia                 5752
# codigo_ocorrencia1                5752
# codigo_ocorrencia2                5752
# codigo_ocorrencia3                5752
# codigo_ocorrencia4                5752
# ocorrencia_classificacao             3
# ocorrencia_latitude               2480
# ocorrencia_longitude              2476
# ocorrencia_cidade                 1099
# ocorrencia_uf                       28
# ocorrencia_pais                      1
# ocorrencia_aerodromo               515
# ocorrencia_dia                    2971
# ocorrencia_hora                    967
# investigacao_aeronave_liberada       3
# investigacao_status                  2
# divulgacao_relatorio_numero       1677
# divulgacao_relatorio_publicado       2
# divulgacao_dia_publicacao          215
# total_recomendacoes                 17
# total_aeronaves_envolvidas           3
# ocorrencia_saida_pista               2
# dtype: int64

# %%
df_oco = df_oco.drop('divulgacao_dia_publicacao', axis =1)

# %%
df_oco = df_oco.dropna()

# %%
df_oco = df_oco['ocorrencia_latitude'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-13f34d3a27c7> in <module>
# ----> 1 df_oco = df_oco['ocorrencia_latitude'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
#Visualização dos Acidentes no Mapa
import plotly.express as px 
houses =  df_oco [['codigo_ocorrencia', 'ocorrencia_latitude', 'ocorrencia_longitude','total_recomendacoes']]
fig=px.scatter_mapbox( houses, 
                      lat = 'ocorrencia_latitude', 
                      lon ='ocorrencia_longitude',
                      size= 'total_recomendacoes',
                      color_continuous_scale= px.colors.cyclical.IceFire,
                      zoom=10)
fig.update_layout(mapbox_style= 'open-street-map')
fig.update_layout(height=600, margin={'r': 0, 't':0, 'l':0, 'b':0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1543         try:
# -> 1544             x = float(x)
#    1545         except ValueError:
#
# ...

# %%
df_oco.isnull().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               1565
# ocorrencia_longitude              1565
# ocorrencia_cidade                    0
# ocorrencia_uf                        0
# ocorrencia_pais                      0
# ocorrencia_aerodromo                 0
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada     341
# investigacao_status                340
# divulgacao_relatorio_numero        865
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [markdown]
# O problema desse dataframe é a coluna [divulgacao_dia_publicacao]

# %%
df_oco.shape
# Out:
# (5752, 22)

# %% [markdown]
# #  Data Cleaning
# Há dois dataframes que precisam ser limpos antes de fazer o merge. Além de que há muitos dados sujos como (****)

# %%
df_oco.dropna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 3                 39527               39527               39527
# 7                 39707               39707               39707
# 8                 39156               39156               39156
# 11                40069               40069               40069
# 13                39507               39507               39507
# ...                 ...                 ...                 ...
# 5308              79128               79128               79128
# 5326              79198               79198               79198
# 5329              79195               79195               79195
# 5479              79397               79397               79397
# 5514              79445               79445               79445
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 3                  39527               39527                 ACIDENTE
# ...

# %%
df_aero.dropna()
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 0                  39115              PTNQX                         ***
# 1                  39155              PTLVI                         ***
# 2                  39156              PPPTO                         ***
# 3                  39158              PRLGJ                     REGULAR
# 4                  39176              PRMAA                     REGULAR
# ...                  ...                ...                         ...
# 5813               79787              PRYRA                         ***
# 5814               79799              PTERL                         ***
# 5815               79800              PRURN                         ***
# 5816               79802              PRGUF                         ***
# 5818               79824              PRALA                         ***
#
#      aeronave_tipo_veiculo          aeronave_fabricante aeronave_modelo  \
# ...

# %%
df_aero.shape, df_oco.shape, df_ot.shape, df_fc.shape
# Out:
# ((5821, 23), (5752, 22), (5884, 4), (4161, 5))

# %% [markdown]
# # Agrupando as tabelas

# %%
# df1.merge(df2, left_on='lkey', right_on='rkey')
df_m =df_aero.merge(df_oco)

# %%
df_m.loc[df_m["aeronave_ano_fabricacao"] == 9999]
# Out:
#       codigo_ocorrencia2 aeronave_matricula aeronave_operador_categoria  \
# 4094               66826              PUCCO                         ***
#
#      aeronave_tipo_veiculo aeronave_fabricante   aeronave_modelo  \
# 4094             ULTRALEVE          NORTH LAND  NORTH LAND PA-18
#
#      aeronave_tipo_icao aeronave_motor_tipo aeronave_motor_quantidade  \
# 4094               ULAC              PISTÃO                       ***
#
#       aeronave_pmd  ...  ocorrencia_dia  ocorrencia_hora  \
# 4094           750  ...      2017-06-02         18:30:00
#
#       investigacao_aeronave_liberada investigacao_status  \
# 4094                             SIM                 NaN
#
#      divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 4094                         NaN                            NÃO
#
#      divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 4094                       NaN                   0                          1
#
# ...
